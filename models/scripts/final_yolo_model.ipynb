# %%
import os
import json
from pathlib import Path

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import cv2
from PIL import Image

import torch
from torchvision import transforms
import timm
from ultralytics import YOLO

from tqdm import tqdm

# %%
model = YOLO("yolov8n.pt")
model.info()
# Out:
# YOLOv8n summary: 129 layers, 3,157,200 parameters, 0 gradients, 8.9 GFLOPs
# (129, 3157200, 0, 8.8575488)

# %%
print("CUDA 사용 가능 여부:", torch.cuda.is_available())
print("사용 중인 디바이스:", torch.cuda.get_device_name(0))
# Out:
# CUDA 사용 가능 여부: True
# 사용 중인 디바이스: NVIDIA GeForce RTX 5080

# %%
results = model.train(
    data='./dataset.yaml',  # 너가 만든 YAML 경로로 수정
    epochs=100,
    batch=16,  # GPU 메모리에 따라 조정
    imgsz=640,
    device=0,
    cache=True
)

# %%
model = YOLO("./best.pt")

train_results = model.predict(
    source="./test_images",     # 테스트 이미지 디렉토리
    conf=0.3,                  # confidence threshold
    imgsz=640,                  # 이미지 크기
    save=True,                  # 예측 결과 이미지 저장
    save_txt=True,              # 바운딩 박스 txt 저장
    save_conf=True,             # confidence 점수까지 포함
    show_labels=True,           # 이미지에 라벨 표시
    show_conf=True,             # confidence score 표시
    name="predict"              # 저장 디렉토리 이름
)
# Out:
# image 1/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1.png: 640x512 1  5mg, 1  800mg, 1  10mg, 1 , 33.8ms
# image 2/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\10.png: 640x512 1  5mg, 1  100mg, 1  20mg, 1 , 9.7ms
# image 3/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\100.png: 640x512 1  5mg, 1  100mg, 1  30mg, 1 , 8.5ms
# image 4/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1003.png: 640x512 1 ()(), 1  20mg, 1  40/5mg, 1  50/1000mg, 9.3ms
# image 5/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1004.png: 640x512 1 ()(), 1  20mg, 1  40/5mg, 1  50/1000mg, 9.8ms
# image 6/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1005.png: 640x512 1 ()(), 1  20mg, 1  40/5mg, 1  50/1000mg, 9.3ms
# image 7/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1006.png: 640x512 1 ()(), 1  75mg, 1  50/850mg, 1  5/100mg, 8.7ms
# image 8/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1007.png: 640x512 1 ()(), 1  75mg, 1  50/850mg, 1  5/100mg, 5.0ms
# image 9/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1009.png: 640x512 1 ()(), 1  20mg, 1  50mg, 1  5/100mg, 4.1ms
# image 10/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1010.png: 640x512 1 ()(), 1  20mg, 1  50mg, 1  5/100mg, 9.3ms
# image 11/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1012.png: 640x512 1  5mg, 1  100mg, 1  10mg, 1 , 8.7ms
# image 12/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1013.png: 640x512 1  5mg, 1  100mg, 1  10mg, 1 , 10.0ms
# image 13/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1014.png: 640x512 1  5mg, 1  100mg, 1  10mg, 1 , 9.2ms
# image 14/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1015.png: 640x512 1 ()(), 1  5/160mg, 1  2.5/850mg, 1  10/40mg, 9.3ms
# image 15/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1016.png: 640x512 1 ()(), 1  5/160mg, 1  2.5/850mg, 1  10/40mg, 4.1ms
# image 16/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1018.png: 640x512 1 ()(), 1  40/5mg, 1  4mg, 1  2.5/850mg, 9.1ms
# image 17/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1019.png: 640x512 1 ()(), 1  40/5mg, 1  4mg, 1  2.5/850mg, 9.3ms
# image 18/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\102.png: 640x512 1  5mg, 1  100mg, 1  30mg, 1 , 4.6ms
# image 19/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1020.png: 640x512 1 ()(), 1  40/5mg, 1  4mg, 1  2.5/850mg, 5.4ms
# image 20/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1022.png: 640x512 1  5mg, 1  800mg, 1 , 1  20mg, 8.1ms
# image 21/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1023.png: 640x512 1  5mg, 1  800mg, 1 , 1  20mg, 4.6ms
# image 22/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1025.png: 640x512 1 ()(), 1  20mg, 1  5/160mg, 1 (), 10.1ms
# image 23/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1026.png: 640x512 1 ()(), 1  20mg, 1  5/160mg, 1 (), 8.5ms
# image 24/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1027.png: 640x512 1  2mg, 1 ()(), 1  20mg, 1  20mg, 4.1ms
# image 25/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1028.png: 640x512 1  2mg, 1 ()(), 1  20mg, 9.0ms
# image 26/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1029.png: 640x512 1  2mg, 1 ()(), 1  20mg, 10.4ms
# image 27/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1030.png: 640x512 1 ()(), 1  40/5mg, 1  50/1000mg, 1  10/40mg, 4.5ms
# image 28/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1034.png: 640x512 1 ()(), 1  5mg, 1 (), 1 10/5, 9.8ms
# image 29/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1039.png: 640x512 1 ()(), 1  20mg, 1  5/100mg, 1 (), 6.3ms
# image 30/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\104.png: 640x512 1  2mg, 1 (), 1  10mg, 9.6ms
# image 31/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1041.png: 640x512 1 ()(), 1  20mg, 1  5/100mg, 1 (), 6.5ms
# image 32/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1043.png: 640x512 1  2mg, 1 (), 1  10/40mg, 10.0ms
# image 33/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1044.png: 640x512 1  2mg, 1 (), 1  10/40mg, 9.1ms
# image 34/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1045.png: 640x512 1 ()(), 1  5/160mg, 1 (), 1  4mg, 5.0ms
# image 35/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1046.png: 640x512 1 ()(), 1  5/160mg, 1 (), 1  4mg, 9.0ms
# image 36/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1047.png: 640x512 1 ()(), 1  5/160mg, 1 (), 1  4mg, 4.5ms
# image 37/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1050.png: 640x512 1  100mg, 1 , 1  300mg, 1  90mg/, 4.2ms
# image 38/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1051.png: 640x512 1  100mg, 1 500mg, 1 , 1  100mg/, 9.0ms
# image 39/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1053.png: 640x512 1  100mg, 1 500mg, 1 , 1  100mg/, 5.0ms
# image 40/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1055.png: 640x512 1 ()(), 1  40/5mg, 1  4mg, 1  100/1000mg, 9.8ms
# image 41/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1056.png: 640x512 1 ()(), 1  40/5mg, 1  4mg, 1  100/1000mg, 4.3ms
# image 42/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1057.png: 640x512 1  100mg, 1 500mg, 1  10mg/, 1  31.5mg/PTP, 3.7ms
# image 43/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1058.png: 640x512 1  100mg, 1 500mg, 1  10mg/, 1  31.5mg/PTP, 3.9ms
# image 44/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1060.png: 640x512 1  100mg, 1 8 650mg, 1  90mg/, 1  31.5mg/PTP, 4.9ms
# image 45/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1064.png: 640x512 1 ()(), 1  75mg, 1  5/100mg, 1  50/1000mg, 9.1ms
# image 46/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1065.png: 640x512 1 ()(), 1  75mg, 1  5/100mg, 1  50/1000mg, 5.6ms
# image 47/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1067.png: 640x512 1 ()(), 1  20mg, 1  10/40mg, 1  100/1000mg, 4.5ms
# image 48/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1069.png: 640x512 1  5mg, 1  100mg, 1 (), 1  20mg, 5.5ms
# image 49/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1070.png: 640x512 1  5mg, 1  100mg, 1 (), 1  20mg, 12.8ms
# image 50/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1073.png: 640x512 1 ()(), 1  50mg, 1  60mg, 1 10/5, 5.7ms
# image 51/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1075.png: 640x512 1 ()(), 1 (), 1  800mg, 1  15mg, 7.5ms
# image 52/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1076.png: 640x512 1 ()(), 1 (), 1  800mg, 1  15mg, 5.7ms
# image 53/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1077.png: 640x512 1 ()(), 1 (), 1  800mg, 1  15mg, 4.3ms
# image 54/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1079.png: 640x512 1 ()(), 1  5/160mg, 1  50mg, 1  4mg, 9.4ms
# image 55/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\108.png: 640x512 1  100mg, 1  10mg/, 1  300mg, 1  31.5mg/PTP, 9.2ms
# image 56/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1080.png: 640x512 1 ()(), 1  5/160mg, 1  50mg, 1  4mg, 3.8ms
# image 57/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1081.png: 640x512 1  5mg, 1  800mg, 1 (), 1  50mg, 8.4ms
# image 58/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1085.png: 640x512 1 ()(), 1  20mg, 1  5/160mg, 1  50/850mg, 5.7ms
# image 59/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1087.png: 640x512 1 ()(), 1  100mg, 1  800mg, 1  500/20mg, 8.8ms
# image 60/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1089.png: 640x512 1 ()(), 1  100mg, 1  800mg, 1  500/20mg, 4.5ms
# image 61/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\109.png: 640x512 1 ()(), 1  5mg, 1  50/850mg, 1  10/40mg, 8.5ms
# image 62/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1092.png: 640x512 1  5mg, 1  100mg, 1 , 1  50mg, 8.5ms
# image 63/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1093.png: 640x512 1 ()(), 1  20mg, 1  5mg, 1  50/1000mg, 9.0ms
# image 64/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1095.png: 640x512 1 ()(), 1  20mg, 1  5mg, 1  50/1000mg, 8.3ms
# image 65/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1096.png: 640x512 1 ()(), 1  200mg, 1  800mg, 1  100mg, 4.1ms
# image 66/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1097.png: 640x512 1 ()(), 1  200mg, 1  800mg, 1  100mg, 4.1ms
# image 67/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1098.png: 640x512 1 ()(), 1  200mg, 1  800mg, 1  100mg, 4.9ms
# image 68/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\110.png: 640x512 1 ()(), 1  5mg, 1  50/850mg, 1  10/40mg, 5.0ms
# image 69/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1100.png: 640x512 1 ()(), 1  60mg, 1  100/1000mg, 1 10/5, 5.8ms
# image 70/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1101.png: 640x512 1 ()(), 1  60mg, 1  100/1000mg, 1 10/5, 5.9ms
# image 71/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1105.png: 640x512 1 ()(), 1  50mg, 1  40/5mg, 1  10/40mg, 4.5ms
# image 72/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1109.png: 640x512 1 ()(), 1  20mg, 1  10/40mg, 1 (), 4.1ms
# image 73/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1111.png: 640x512 1 ()(), 1  10/40mg, 1 (), 1  4mg, 4.9ms
# image 74/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1114.png: 640x512 1 ()(), 1  10/40mg, 1  2.5/850mg, 1  10/40mg, 5.1ms
# image 75/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1115.png: 640x512 1 ()(), 1  10/40mg, 1  2.5/850mg, 1  10/40mg, 4.8ms
# image 76/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1116.png: 640x512 1 ()(), 1  10/40mg, 1  2.5/850mg, 1  10/40mg, 5.8ms
# image 77/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1118.png: 640x512 1 ()(), 1  200mg, 1  100mg, 1  15mg, 4.8ms
# image 78/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1119.png: 640x512 1 ()(), 1  200mg, 1  100mg, 1  15mg, 5.2ms
# image 79/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\112.png: 640x512 1 ()(), 1  100mg, 1  800mg, 1 , 4.8ms
# image 80/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1121.png: 640x512 1 ()(), 1  5/100mg, 1 (), 1  4mg, 4.7ms
# image 81/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1123.png: 640x512 1 ()(), 1  20mg, 1  50/850mg, 1  40/5mg, 4.8ms
# image 82/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1125.png: 640x512 1 ()(), 1  20mg, 1  50/850mg, 1  40/5mg, 5.3ms
# image 83/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1126.png: 640x512 1 ()(), 1  20mg, 1  5/160mg, 1  100/1000mg, 5.1ms
# image 84/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1129.png: 640x512 1 ()(), 1  75mg, 1  50mg, 1  40/5mg, 4.0ms
# image 85/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\113.png: 640x512 1 ()(), 1  100mg, 1  800mg, 1 , 4.3ms
# image 86/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1135.png: 640x512 1  5mg, 1  800mg, 1  30mg, 1 , 4.1ms
# image 87/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1136.png: 640x512 1  5mg, 1  800mg, 1  30mg, 1 , 4.0ms
# image 88/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1138.png: 640x512 1 ()(), 1  75mg, 1  10/40mg, 1  50/1000mg, 5.4ms
# image 89/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\114.png: 640x512 1 ()(), 1  100mg, 1  800mg, 1 , 5.0ms
# image 90/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1140.png: 640x512 1 ()(), 1  75mg, 1  10/40mg, 1  50/1000mg, 6.0ms
# image 91/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1141.png: 640x512 1  100mg, 1  300mg/PTP, 1  100mg/, 1  31.5mg/PTP, 4.4ms
# image 92/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1142.png: 640x512 1  100mg, 1  300mg/PTP, 1  100mg/, 1  31.5mg/PTP, 7.6ms
# image 93/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1143.png: 640x512 1  100mg, 1  300mg/PTP, 1  100mg/, 1  31.5mg/PTP, 5.8ms
# image 94/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1144.png: 640x512 1 ()(), 1  20mg, 1  5/100mg, 1  100/1000mg, 5.3ms
# image 95/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1148.png: 640x512 1  2mg, 1  20mg, 1  25mg, 5.5ms
# image 96/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1149.png: 640x512 1  2mg, 1  20mg, 1  25mg, 5.1ms
# image 97/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\115.png: 640x512 1 ()(), 1  50/850mg, 1  40/5mg, 1 10/5, 4.7ms
# image 98/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1150.png: 640x512 1 ()(), 1  60mg, 1  4mg, 1  50/1000mg, 4.8ms
# image 99/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1153.png: 640x512 1 ()(), 1  20mg, 1  5mg, 1  50mg, 5.4ms
# image 100/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1154.png: 640x512 1 ()(), 1  20mg, 1  5mg, 1  50mg, 4.3ms
# image 101/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1155.png: 640x512 1 ()(), 1  20mg, 1  5mg, 1  50mg, 5.3ms
# image 102/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1156.png: 640x512 1  2mg, 1 ()(), 1  20mg, 4.9ms
# image 103/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1157.png: 640x512 1  2mg, 1 ()(), 1  20mg, 4.9ms
# image 104/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1158.png: 640x512 1  2mg, 1 ()(), 1  20mg, 6.1ms
# image 105/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1159.png: 640x512 1  2mg, 1  20mg, 1 (), 5.6ms
# image 106/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1161.png: 640x512 1  2mg, 1  20mg, 1 (), 4.4ms
# image 107/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1163.png: 640x512 1 ()(), 1  100mg, 1  800mg, 1 , 5.4ms
# image 108/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1164.png: 640x512 1 ()(), 1  100mg, 1  800mg, 1 , 4.3ms
# image 109/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1166.png: 640x512 1 ()(), 1  50/850mg, 1  5/100mg, 1 10/5, 5.1ms
# image 110/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1167.png: 640x512 1 ()(), 1  50/850mg, 1  5/100mg, 1 10/5, 3.7ms
# image 111/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1168.png: 640x512 1 ()(), 1  5/100mg, 1  4mg, 1  2.5/850mg, 5.7ms
# image 112/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1170.png: 640x512 1 ()(), 1  5/100mg, 1  4mg, 1  2.5/850mg, 4.2ms
# image 113/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1171.png: 640x512 1 ()(), 1 (), 1  100mg, 1  100mg, 5.7ms
# image 114/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1173.png: 640x512 1 ()(), 1 (), 1  100mg, 1  100mg, 9.0ms
# image 115/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1174.png: 640x512 1 ()(), 1  10/40mg, 1  4mg, 1  2.5/850mg, 4.0ms
# image 116/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1176.png: 640x512 1 ()(), 1  10/40mg, 1  4mg, 1  2.5/850mg, 5.6ms
# image 117/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1178.png: 640x512 1 ()(), 1  75mg, 1  60mg, 1  100/1000mg, 5.0ms
# image 118/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\118.png: 640x512 1  2mg, 1 ()(), 1 (-3-90), 5.3ms
# image 119/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1180.png: 640x512 1  2mg, 1  400mg, 1  10mg, 5.0ms
# image 120/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1184.png: 640x512 1  5mg, 1  100mg, 1 (), 1  10mg, 5.2ms
# image 121/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1185.png: 640x512 1  5mg, 1  100mg, 1 (), 1  10mg, 4.3ms
# image 122/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1186.png: 640x512 1  100mg, 1 500mg, 1 , 1  60mg/, 5.2ms
# image 123/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1187.png: 640x512 1  100mg, 1 500mg, 1 , 1  60mg/, 5.2ms
# image 124/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1189.png: 640x512 1  100mg, 1 , 1  300mg/PTP, 1  90mg/, 5.4ms
# image 125/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\119.png: 640x512 1  2mg, 1 ()(), 1 (-3-90), 4.0ms
# image 126/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1190.png: 640x512 1  100mg, 1 , 1  300mg/PTP, 1  90mg/, 4.4ms
# image 127/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1191.png: 640x512 1  100mg, 1 , 1  300mg/PTP, 1  90mg/, 3.8ms
# image 128/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1192.png: 640x512 1  5mg, 1  800mg, 1  10mg, 1 , 4.0ms
# image 129/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1194.png: 640x512 1  5mg, 1  800mg, 1  10mg, 1 , 5.3ms
# image 130/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1196.png: 640x512 1 ()(), 1  60mg, 1 (), 1  10/40mg, 4.2ms
# image 131/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1197.png: 640x512 1 ()(), 1  60mg, 1 (), 1  10/40mg, 5.5ms
# image 132/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1198.png: 640x512 1 ()(), 1  75mg, 1  60mg, 1 (), 5.4ms
# image 133/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1199.png: 640x512 1 ()(), 1  75mg, 1  60mg, 1 (), 4.0ms
# image 134/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\120.png: 640x512 1  2mg, 1 ()(), 1 (-3-90), 4.9ms
# image 135/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1201.png: 640x512 1 ()(), 1  10mg, 1  100mg, 1 (), 8.4ms
# image 136/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1204.png: 640x512 1  2mg, 1  20mg, 1 , 4.6ms
# image 137/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1206.png: 640x512 1  2mg, 1  20mg, 1 , 5.2ms
# image 138/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1207.png: 640x512 1 ()(), 1  20mg, 1  50mg, 1  60mg, 4.3ms
# image 139/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1209.png: 640x512 1 ()(), 1  20mg, 1  50mg, 1  60mg, 4.8ms
# image 140/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1210.png: 640x512 1 ()(), 1  5/160mg, 1  50/1000mg, 1  10/40mg, 5.5ms
# image 141/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1212.png: 640x512 1 ()(), 1  5/160mg, 1  50/1000mg, 1  10/40mg, 5.3ms
# image 142/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1213.png: 640x512 1  100mg, 1 ()(), 1  90mg/, 1  31.5mg/PTP, 3.9ms
# image 143/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1214.png: 640x512 1  100mg, 1 ()(), 1  90mg/, 1  31.5mg/PTP, 6.1ms
# image 144/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1216.png: 640x512 1 ()(), 1  100mg, 1  800mg, 1 , 5.1ms
# image 145/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1219.png: 640x512 1 ()(), 1  100mg, 1  800mg, 1  500/20mg, 5.7ms
# image 146/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\122.png: 640x512 1 ()(), 1  50/850mg, 1  5/100mg, 1  4mg, 5.5ms
# image 147/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1220.png: 640x512 1 ()(), 1  100mg, 1  800mg, 1  500/20mg, 4.0ms
# image 148/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1222.png: 640x512 1 ()(), 1  50/850mg, 1  10/40mg, 1 10/5, 5.5ms
# image 149/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1224.png: 640x512 1 ()(), 1  50/850mg, 1  10/40mg, 1 10/5, 5.1ms
# image 150/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1226.png: 640x512 1 ()(), 1  5mg, 1  100/1000mg, 1  10/40mg, 5.4ms
# image 151/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1227.png: 640x512 1 ()(), 1  5mg, 1  100/1000mg, 1  10/40mg, 5.0ms
# image 152/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1232.png: 640x512 1 ()(), 1  5/160mg, 1  4mg, 1  100/1000mg, 5.6ms
# image 153/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1235.png: 640x512 1  5mg, 1  100mg, 1  20mg, 1 , 4.9ms
# image 154/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1237.png: 640x512 1  5mg, 1  100mg, 1  500/20mg, 1  50mg, 4.2ms
# image 155/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1238.png: 640x512 1  5mg, 1  100mg, 1  500/20mg, 1  50mg, 4.0ms
# image 156/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1239.png: 640x512 1  5mg, 1  100mg, 1  500/20mg, 1  50mg, 5.5ms
# image 157/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\124.png: 640x512 1  5mg, 1  800mg, 1 (), 1  20mg, 4.5ms
# image 158/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1242.png: 640x512 1  5mg, 1  800mg, 1  500/20mg, 1  50mg, 5.3ms
# image 159/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1243.png: 640x512 1 ()(), 1  40/5mg, 1  2.5/850mg, 1  10/40mg, 5.0ms
# image 160/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1244.png: 640x512 1 ()(), 1  40/5mg, 1  2.5/850mg, 1  10/40mg, 7.7ms
# image 161/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1245.png: 640x512 1 ()(), 1  40/5mg, 1  2.5/850mg, 1  10/40mg, 5.5ms
# image 162/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1246.png: 640x512 1 ()(), 1  20mg, 1  60mg, 1  50/1000mg, 4.3ms
# image 163/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1248.png: 640x512 1 ()(), 1  20mg, 1  60mg, 1  50/1000mg, 5.2ms
# image 164/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\125.png: 640x512 1  5mg, 1  800mg, 1 (), 1  20mg, 4.4ms
# image 165/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1250.png: 640x512 1  100mg, 1 500mg, 1 , 1  10mg/, 5.0ms
# image 166/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1251.png: 640x512 1  100mg, 1 500mg, 1 , 1  10mg/, 5.2ms
# image 167/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1252.png: 640x512 1 ()(), 1  5/160mg, 1  4mg, 1  2.5/850mg, 4.5ms
# image 168/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1254.png: 640x512 1 ()(), 1  5/160mg, 1  4mg, 1  2.5/850mg, 3.6ms
# image 169/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1256.png: 640x512 1  5mg, 1  800mg, 1  10mg, 1  500/20mg, 3.8ms
# image 170/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\126.png: 640x512 1  5mg, 1  800mg, 1 (), 1  20mg, 4.4ms
# image 171/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1261.png: 640x512 1 ()(), 1  20mg, 1  50mg, 1  10/40mg, 4.2ms
# image 172/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1262.png: 640x512 1 ()(), 1  20mg, 1  50mg, 1  10/40mg, 4.4ms
# image 173/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1263.png: 640x512 1 ()(), 1  20mg, 1  50mg, 1  10/40mg, 4.5ms
# image 174/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1264.png: 640x512 1  2mg, 1 (), 1 10/5, 9.0ms
# image 175/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1265.png: 640x512 1  2mg, 1 (), 1 10/5, 4.6ms
# image 176/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1266.png: 640x512 1  2mg, 1 (), 1 10/5, 4.3ms
# image 177/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1269.png: 640x512 1  2mg, 1 ()(), 1 10/5, 4.3ms
# image 178/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\127.png: 640x512 1  100mg, 1 , 1  618.6mg/, 1  300mg, 4.8ms
# image 179/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1270.png: 640x512 1  5mg, 1  100mg, 1  30mg, 1 , 4.0ms
# image 180/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1272.png: 640x512 1  5mg, 1  100mg, 1  30mg, 1 , 4.1ms
# image 181/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1273.png: 640x512 1  100mg, 1 ()(), 1  618.6mg/, 1  31.5mg/PTP, 5.2ms
# image 182/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1274.png: 640x512 1  100mg, 1  618.6mg/, 1 8 650mg, 1  31.5mg/PTP, 9.6ms
# image 183/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1278.png: 640x512 1  2mg, 1 (), 1  10/20mg, 5.1ms
# image 184/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1279.png: 640x512 1  5mg, 1  800mg, 1  20mg, 1  500/20mg, 4.6ms
# image 185/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\128.png: 640x512 1  100mg, 1 , 1  618.6mg/, 1  300mg, 4.8ms
# image 186/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1280.png: 640x512 1  5mg, 1  800mg, 1  20mg, 1  500/20mg, 4.7ms
# image 187/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1282.png: 640x512 1  100mg, 1 , 1 8 650mg, 1  60mg/, 4.4ms
# image 188/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1284.png: 640x512 1  100mg, 1 , 1 8 650mg, 1  60mg/, 4.2ms
# image 189/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\129.png: 640x512 1  100mg, 1 , 1  618.6mg/, 1  300mg, 4.7ms
# image 190/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1290.png: 640x512 1  5mg, 1  100mg, 1  30mg, 1  500/20mg, 4.7ms
# image 191/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1293.png: 640x512 1 ()(), 1  75mg, 1  60mg, 1  2.5/850mg, 5.9ms
# image 192/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1294.png: 640x512 1 ()(), 1  10/40mg, 1  50/1000mg, 1  10/40mg, 4.7ms
# image 193/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1295.png: 640x512 1 ()(), 1  10/40mg, 1  50/1000mg, 1  10/40mg, 8.7ms
# image 194/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1296.png: 640x512 1 ()(), 1  10/40mg, 1  50/1000mg, 1  10/40mg, 4.6ms
# image 195/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1297.png: 640x512 1 ()(), 1 (), 1  2.5mg, 1  100mg, 3.6ms
# image 196/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1298.png: 640x512 1 ()(), 1 (), 1  2.5mg, 1  100mg, 4.6ms
# image 197/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\13.png: 640x512 1  2mg, 1  20mg, 1 (), 4.7ms
# image 198/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\130.png: 640x512 1 ()(), 1  60mg, 1  2.5/850mg, 1 10/5, 4.4ms
# image 199/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1300.png: 640x512 1 ()(), 1  10/40mg, 1  4mg, 1  100/1000mg, 4.5ms
# image 200/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1302.png: 640x512 1 ()(), 1  10/40mg, 1  4mg, 1  100/1000mg, 4.7ms
# image 201/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1305.png: 640x512 1  5mg, 1  800mg, 1 , 1  50mg, 4.1ms
# image 202/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1309.png: 640x512 1 ()(), 1  40/5mg, 1 (), 1  4mg, 4.2ms
# image 203/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1311.png: 640x512 1 ()(), 1  40/5mg, 1 (), 1  4mg, 5.5ms
# image 204/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1312.png: 640x512 1  100mg, 1 , 1 ()(), 1  90mg/, 5.2ms
# image 205/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1315.png: 640x512 1  2mg, 1 (-3-90), 1  400mg, 3.9ms
# image 206/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1316.png: 640x512 1  2mg, 1 (-3-90), 1  400mg, 4.9ms
# image 207/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\132.png: 640x512 1 ()(), 1  60mg, 1  2.5/850mg, 1 10/5, 5.2ms
# image 208/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1322.png: 640x512 1  100mg, 1 500mg, 1 , 1  618.6mg/, 4.0ms
# image 209/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1323.png: 640x512 1  100mg, 1 500mg, 1 , 1  618.6mg/, 3.5ms
# image 210/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1326.png: 640x512 1  2mg, 1 (), 1  75mg, 5.7ms
# image 211/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1327.png: 640x512 1  5mg, 1  100mg, 1 , 1  50mg, 4.7ms
# image 212/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1328.png: 640x512 1  5mg, 1  100mg, 1 , 1  50mg, 4.4ms
# image 213/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1329.png: 640x512 1  5mg, 1  100mg, 1 , 1  50mg, 4.6ms
# image 214/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1330.png: 640x512 1 ()(), 1  5/100mg, 1  50/1000mg, 1  10/40mg, 4.7ms
# image 215/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1331.png: 640x512 1 ()(), 1  5/100mg, 1  50/1000mg, 1  10/40mg, 6.8ms
# image 216/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1332.png: 640x512 1 ()(), 1  5/100mg, 1  50/1000mg, 1  10/40mg, 4.7ms
# image 217/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1333.png: 640x512 1  2mg, 1 , 1 10/5, 4.2ms
# image 218/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1337.png: 640x512 1  5mg, 1  100mg, 1  30mg, 1 , 9.3ms
# image 219/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\134.png: 640x512 1 ()(), 1  10/40mg, 1  100/1000mg, 1  10/40mg, 3.9ms
# image 220/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1340.png: 640x512 1  5mg, 1  100mg, 1  10mg, 1  500/20mg, 5.7ms
# image 221/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1345.png: 640x512 1 ()(), 1  5/100mg, 1  4mg, 1  100/1000mg, 4.5ms
# image 222/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1347.png: 640x512 1 ()(), 1  5/100mg, 1  4mg, 1  100/1000mg, 3.8ms
# image 223/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1348.png: 640x512 1  2mg, 1  20mg, 1 (), 5.2ms
# image 224/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\135.png: 640x512 1 ()(), 1  10/40mg, 1  100/1000mg, 1  10/40mg, 3.9ms
# image 225/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1350.png: 640x512 1  2mg, 1  20mg, 1 (), 8.9ms
# image 226/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1353.png: 640x512 1 ()(), 1  20mg, 1  60mg, 1  50/1000mg, 6.0ms
# image 227/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1354.png: 640x512 1 ()(), 1  5/160mg, 1  2.5/850mg, 1 10/5, 4.0ms
# image 228/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1355.png: 640x512 1 ()(), 1  5/160mg, 1  2.5/850mg, 1 10/5, 4.8ms
# image 229/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1357.png: 640x512 1 ()(), 1  200mg, 1  2.5mg, 1  100mg, 4.1ms
# image 230/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1358.png: 640x512 1 ()(), 1  200mg, 1  2.5mg, 1  100mg, 4.3ms
# image 231/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1359.png: 640x512 1 ()(), 1  200mg, 1  2.5mg, 1  100mg, 4.5ms
# image 232/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\136.png: 640x512 1  5mg, 1  800mg, 1 , 1  50mg, 4.0ms
# image 233/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1361.png: 640x512 1  2mg, 1  400mg, 1  4mg, 3.9ms
# image 234/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1363.png: 640x512 1  2mg, 1  20mg, 1 (), 3.8ms
# image 235/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1366.png: 640x512 1 ()(), 1  50mg, 1  10/40mg, 1  4mg, 5.0ms
# image 236/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1367.png: 640x512 1 ()(), 1  50mg, 1  10/40mg, 1  4mg, 5.2ms
# image 237/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1369.png: 640x512 1 ()(), 1  20mg, 1  5mg, 1  50mg, 4.9ms
# image 238/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1371.png: 640x512 1 ()(), 1  20mg, 1  5mg, 1  50mg, 4.5ms
# image 239/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1372.png: 640x512 1  100mg, 1 , 1 ()(), 1  90mg/, 4.2ms
# image 240/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1376.png: 640x512 1  5mg, 1  800mg, 1 , 1  20mg, 4.2ms
# image 241/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1377.png: 640x512 1  5mg, 1  800mg, 1 , 1  20mg, 4.4ms
# image 242/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1378.png: 640x512 1 ()(), 1  5mg, 1  50mg, 1  10/40mg, 5.0ms
# image 243/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1379.png: 640x512 1 ()(), 1  5mg, 1  50mg, 1  10/40mg, 4.9ms
# image 244/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1381.png: 640x512 1  2mg, 1  10mg, 1 , 3.7ms
# image 245/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1384.png: 640x512 1 ()(), 1  75mg, 1  50/850mg, 1  60mg, 4.3ms
# image 246/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1385.png: 640x512 1 ()(), 1  75mg, 1  50/850mg, 1  60mg, 8.6ms
# image 247/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1386.png: 640x512 1 ()(), 1  75mg, 1  50/850mg, 1  60mg, 4.0ms
# image 248/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1387.png: 640x512 1 ()(), 1  75mg, 1  5/160mg, 1  50mg, 4.2ms
# image 249/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\139.png: 640x512 1 ()(), 1  5/100mg, 1  100/1000mg, 1  10/40mg, 4.9ms
# image 250/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1390.png: 640x512 1  100mg, 1  300mg, 1  90mg/, 1  31.5mg/PTP, 4.3ms
# image 251/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1392.png: 640x512 1  100mg, 1  300mg, 1  90mg/, 1  31.5mg/PTP, 4.2ms
# image 252/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1393.png: 640x512 1 ()(), 1  20mg, 1  50mg, 1  60mg, 4.8ms
# image 253/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1395.png: 640x512 1 ()(), 1  20mg, 1  50mg, 1  60mg, 4.0ms
# image 254/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1396.png: 640x512 1  100mg, 1 , 1 8 650mg, 1  60mg/, 3.9ms
# image 255/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\140.png: 640x512 1 ()(), 1  5/100mg, 1  100/1000mg, 1  10/40mg, 4.9ms
# image 256/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1401.png: 640x512 1 ()(), 1  50mg, 1  5/100mg, 1  4mg, 4.4ms
# image 257/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1402.png: 640x512 1  2mg, 1  75mg, 1 (), 4.2ms
# image 258/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1404.png: 640x512 1  2mg, 1  75mg, 1 (), 5.6ms
# image 259/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1407.png: 640x512 1  2mg, 1 (), 1  10/20mg, 4.3ms
# image 260/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1408.png: 640x512 1  5mg, 1  100mg, 1 (), 1  20mg, 4.3ms
# image 261/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1411.png: 640x512 1 ()(), 1  10/40mg, 1  2.5/850mg, 1 10/5, 4.3ms
# image 262/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1413.png: 640x512 1 ()(), 1  10/40mg, 1  2.5/850mg, 1 10/5, 5.1ms
# image 263/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1414.png: 640x512 1 ()(), 1  100mg, 1  100mg, 1 , 3.7ms
# image 264/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1418.png: 640x512 1  5mg, 1  800mg, 1 , 1  500/20mg, 4.6ms
# image 265/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\142.png: 640x512 1  5mg, 1  100mg, 1 (), 1  50mg, 4.2ms
# image 266/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1420.png: 640x512 1  2mg, 1 (-3-90), 1  25mg, 4.1ms
# image 267/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1421.png: 640x512 1  2mg, 1 (-3-90), 1  25mg, 5.4ms
# image 268/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1424.png: 640x512 1 ()(), 1  60mg, 1  100/1000mg, 1  10/40mg, 3.7ms
# image 269/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1425.png: 640x512 1 ()(), 1  60mg, 1  100/1000mg, 1  10/40mg, 4.0ms
# image 270/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1429.png: 640x512 1 ()(), 1  100mg, 1  100mg, 1  500/20mg, 5.5ms
# image 271/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\143.png: 640x512 1  5mg, 1  100mg, 1 (), 1  50mg, 4.5ms
# image 272/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1431.png: 640x512 1 ()(), 1  100mg, 1  100mg, 1  500/20mg, 5.8ms
# image 273/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1433.png: 640x512 1  2mg, 1 , 1  10/20mg, 9.3ms
# image 274/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1435.png: 640x512 1  2mg, 1 ()(), 1  75mg, 4.6ms
# image 275/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1436.png: 640x512 1  2mg, 1 ()(), 1  75mg, 5.5ms
# image 276/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1438.png: 640x512 1 ()(), 1  200mg, 1  10mg, 1  100mg, 4.4ms
# image 277/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1439.png: 640x512 1 ()(), 1  200mg, 1  10mg, 1  100mg, 4.7ms
# image 278/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1441.png: 640x512 1 ()(), 1  50mg, 1  40/5mg, 1 10/5, 4.2ms
# image 279/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1442.png: 640x512 1 ()(), 1  50mg, 1  40/5mg, 1 10/5, 4.1ms
# image 280/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1444.png: 640x512 1  100mg, 1 , 1 500mg, 1  100mg/, 4.1ms
# image 281/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1446.png: 640x512 1  100mg, 1 , 1 500mg, 1  100mg/, 4.6ms
# image 282/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1447.png: 640x512 1 ()(), 1  100mg, 1  100mg, 1 , 4.4ms
# image 283/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1449.png: 640x512 1 ()(), 1  100mg, 1  100mg, 1 , 3.9ms
# image 284/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1450.png: 640x512 1  100mg, 1  10mg/, 1 8 650mg, 1  31.5mg/PTP, 5.1ms
# image 285/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1452.png: 640x512 1  100mg, 1  10mg/, 1 8 650mg, 1  31.5mg/PTP, 4.7ms
# image 286/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1453.png: 640x512 1  2mg, 1 (-3-90), 1 (), 5.3ms
# image 287/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1455.png: 640x512 1  2mg, 1 (-3-90), 1 (), 3.7ms
# image 288/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1458.png: 640x512 1  100mg, 1 500mg, 1  100mg/, 1  31.5mg/PTP, 5.2ms
# image 289/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1459.png: 640x512 1  100mg, 1 , 1  300mg/PTP, 1  90mg/, 4.9ms
# image 290/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\146.png: 640x512 1 ()(), 1  20mg, 1  60mg, 1  100/1000mg, 5.1ms
# image 291/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1460.png: 640x512 1  100mg, 1 , 1  300mg/PTP, 1  90mg/, 4.5ms
# image 292/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1461.png: 640x512 1  100mg, 1 , 1  300mg/PTP, 1  90mg/, 4.1ms
# image 293/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1462.png: 640x512 1 ()(), 1  75mg, 1  50/850mg, 1  10/40mg, 4.2ms
# image 294/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1463.png: 640x512 1 ()(), 1  75mg, 1  50/850mg, 1  10/40mg, 6.0ms
# image 295/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1464.png: 640x512 1 ()(), 1  75mg, 1  50/850mg, 1  10/40mg, 4.8ms
# image 296/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1466.png: 640x512 1 ()(), 1  20mg, 1  50mg, 1  10/40mg, 5.0ms
# image 297/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1473.png: 640x512 1  5mg, 1  800mg, 1  10mg, 1 (), 5.6ms
# image 298/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1474.png: 640x512 1 ()(), 1  40/5mg, 1  50/1000mg, 1 10/5, 4.5ms
# image 299/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1476.png: 640x512 1 ()(), 1  40/5mg, 1  50/1000mg, 1 10/5, 5.7ms
# image 300/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1477.png: 640x512 1  2mg, 1 (), 1 10/5, 5.2ms
# image 301/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\148.png: 640x512 1  2mg, 1  400mg, 1  75mg, 5.2ms
# image 302/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1480.png: 640x512 1 ()(), 1  200mg, 1  100mg, 1  100mg, 4.0ms
# image 303/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1483.png: 640x512 1 ()(), 1  5mg, 1 (), 1  10/40mg, 3.8ms
# image 304/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1485.png: 640x512 1 ()(), 1  5mg, 1 (), 1  10/40mg, 3.9ms
# image 305/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1488.png: 640x512 1  2mg, 1  10mg, 1 (), 3.6ms
# image 306/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1489.png: 640x512 1  2mg, 1 , 1  75mg, 4.3ms
# image 307/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\149.png: 640x512 1  2mg, 1  400mg, 1  75mg, 5.4ms
# image 308/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1492.png: 640x512 1  2mg, 1  150mg, 1  10mg, 4.7ms
# image 309/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1493.png: 640x512 1  2mg, 1  150mg, 1  10mg, 3.9ms
# image 310/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1497.png: 640x512 1 ()(), 1  5mg, 1  4mg, 1  50/1000mg, 4.5ms
# image 311/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\15.png: 640x512 1  2mg, 1  20mg, 1 (), 5.1ms
# image 312/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\150.png: 640x512 1  2mg, 1  400mg, 1  75mg, 4.8ms
# image 313/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\1500.png: 640x512 1  2mg, 1  10/20mg, 1  25mg, 4.0ms
# image 314/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\151.png: 640x512 1  5mg, 1  100mg, 1 , 1  20mg, 4.4ms
# image 315/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\152.png: 640x512 1  5mg, 1  100mg, 1 , 1  20mg, 4.6ms
# image 316/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\153.png: 640x512 1  5mg, 1  100mg, 1 , 1  20mg, 4.0ms
# image 317/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\154.png: 640x512 1  100mg, 1 , 1 ()(), 1  100mg/, 5.9ms
# image 318/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\155.png: 640x512 1  100mg, 1 , 1 ()(), 1  100mg/, 4.2ms
# image 319/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\156.png: 640x512 1  100mg, 1 , 1 ()(), 1  100mg/, 3.7ms
# image 320/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\157.png: 640x512 1 ()(), 1  20mg, 1  50/850mg, 1  60mg, 4.8ms
# image 321/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\159.png: 640x512 1 ()(), 1  20mg, 1  50/850mg, 1  60mg, 4.6ms
# image 322/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\160.png: 640x512 1 ()(), 1 (), 1  800mg, 1  25mg, 3.9ms
# image 323/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\162.png: 640x512 1 ()(), 1 (), 1  800mg, 1  25mg, 4.7ms
# image 324/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\163.png: 640x512 1 ()(), 1  20mg, 1  60mg, 1 (), 4.3ms
# image 325/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\164.png: 640x512 1 ()(), 1  20mg, 1  60mg, 1 (), 7.3ms
# image 326/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\165.png: 640x512 1 ()(), 1  20mg, 1  60mg, 1 (), 4.5ms
# image 327/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\17.png: 640x512 1  2mg, 1  10/40mg, 1  25mg, 4.7ms
# image 328/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\170.png: 640x512 1  100mg, 1 , 1  618.6mg/, 1  300mg/PTP, 4.4ms
# image 329/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\172.png: 640x512 1 ()(), 1  50/850mg, 1  10/40mg, 1  4mg, 4.3ms
# image 330/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\173.png: 640x512 1 ()(), 1  50/850mg, 1  10/40mg, 1  4mg, 5.5ms
# image 331/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\174.png: 640x512 1 ()(), 1  50/850mg, 1  10/40mg, 1  4mg, 4.6ms
# image 332/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\175.png: 640x512 1 ()(), 1  5mg, 1  4mg, 1  2.5/850mg, 4.6ms
# image 333/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\176.png: 640x512 1 ()(), 1  5mg, 1  4mg, 1  2.5/850mg, 4.3ms
# image 334/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\179.png: 640x512 1 ()(), 1  75mg, 1  50mg, 1  60mg, 3.8ms
# image 335/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\180.png: 640x512 1 ()(), 1  75mg, 1  50mg, 1  60mg, 3.6ms
# image 336/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\183.png: 640x512 1 ()(), 1  200mg, 1  100mg, 1  800mg, 4.5ms
# image 337/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\185.png: 640x512 1 ()(), 1 (), 1  100mg, 1  25mg, 4.1ms
# image 338/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\186.png: 640x512 1 ()(), 1 (), 1  100mg, 1  25mg, 3.7ms
# image 339/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\189.png: 640x512 1  100mg, 1 , 1  10mg/, 1  300mg, 3.9ms
# ...
# image 732/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\819.png: 640x512 1 ()(), 1  20mg, 1  10/40mg, 1  2.5/850mg, 4.0ms
# image 733/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\82.png: 640x512 1  100mg, 1 , 1  60mg/, 1  300mg, 5.2ms
# image 734/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\820.png: 640x512 1  100mg, 1 , 1 500mg, 1  60mg/, 4.3ms
# image 735/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\822.png: 640x512 1  100mg, 1 , 1 500mg, 1  60mg/, 4.3ms
# image 736/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\826.png: 640x512 1  2mg, 1  150mg, 1  10/20mg, 5.4ms
# image 737/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\828.png: 640x512 1  2mg, 1  150mg, 1  10/20mg, 5.8ms
# image 738/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\829.png: 640x512 1 ()(), 1  60mg, 1 (), 1 10/5, 5.2ms
# image 739/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\83.png: 640x512 1  100mg, 1 , 1  60mg/, 1  300mg, 5.0ms
# image 740/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\830.png: 640x512 1 ()(), 1  60mg, 1 (), 1 10/5, 4.6ms
# image 741/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\831.png: 640x512 1 ()(), 1  60mg, 1 (), 1 10/5, 4.4ms
# image 742/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\832.png: 640x512 1  5mg, 1  100mg, 1  30mg, 1 (), 5.3ms
# image 743/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\838.png: 640x512 1  5mg, 1  100mg, 1 , 1  20mg, 4.6ms
# image 744/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\842.png: 640x512 1 ()(), 1  20mg, 1  40/5mg, 1  50/1000mg, 5.6ms
# image 745/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\85.png: 640x512 1  5mg, 1  100mg, 1  20mg, 1  500/20mg, 4.9ms
# image 746/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\851.png: 640x512 1  100mg, 1 , 1  300mg, 1  90mg/, 6.1ms
# image 747/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\855.png: 640x512 1  100mg, 1 , 1 500mg, 1  10mg/, 4.7ms
# image 748/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\857.png: 640x512 1  2mg, 1  20mg, 1 (), 4.9ms
# image 749/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\858.png: 640x512 1  2mg, 1  20mg, 1 (), 6.2ms
# image 750/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\86.png: 640x512 1  5mg, 1  100mg, 1  20mg, 1  500/20mg, 4.0ms
# image 751/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\861.png: 640x512 1  100mg, 1  300mg/PTP, 1  60mg/, 1  31.5mg/PTP, 7.3ms
# image 752/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\862.png: 640x512 1 ()(), 1  5/100mg, 1  50/1000mg, 1 10/5, 4.9ms
# image 753/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\864.png: 640x512 1 ()(), 1  5/100mg, 1  50/1000mg, 1 10/5, 5.1ms
# image 754/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\866.png: 640x512 1  2mg, 1 (), 1 (-3-90), 5.1ms
# image 755/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\867.png: 640x512 1  2mg, 1 (), 1 (-3-90), 4.5ms
# image 756/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\868.png: 640x512 1 ()(), 1  20mg, 1  10/40mg, 1  100/1000mg, 4.1ms
# image 757/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\869.png: 640x512 1 ()(), 1  20mg, 1  10/40mg, 1  100/1000mg, 5.3ms
# image 758/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\870.png: 640x512 1 ()(), 1  20mg, 1  10/40mg, 1  100/1000mg, 4.0ms
# image 759/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\873.png: 640x512 1  2mg, 1 (-3-90), 1  150mg, 4.0ms
# image 760/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\874.png: 640x512 1 ()(), 1  20mg, 1  5/160mg, 1  100/1000mg, 4.6ms
# image 761/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\875.png: 640x512 1 ()(), 1  20mg, 1  5/160mg, 1  100/1000mg, 4.8ms
# image 762/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\878.png: 640x512 1 ()(), 1  10/40mg, 1  50/1000mg, 1 10/5, 4.2ms
# image 763/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\879.png: 640x512 1 ()(), 1  10/40mg, 1  50/1000mg, 1 10/5, 5.4ms
# image 764/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\88.png: 640x512 1  5mg, 1  800mg, 1  30mg, 1  500/20mg, 4.1ms
# image 765/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\880.png: 640x512 1  100mg, 1 , 1 8 650mg, 1  100mg/, 4.1ms
# image 766/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\882.png: 640x512 1  100mg, 1 , 1 8 650mg, 1  100mg/, 5.6ms
# image 767/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\883.png: 640x512 1 ()(), 1  20mg, 1  5/100mg, 1 (), 5.2ms
# image 768/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\886.png: 640x512 1  2mg, 1 (), 1  10/40mg, 3.8ms
# image 769/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\888.png: 640x512 1  2mg, 1 (), 1  10/40mg, 5.4ms
# image 770/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\889.png: 640x512 1 ()(), 1  20mg, 1  5/160mg, 1 (), 5.2ms
# image 771/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\89.png: 640x512 1  5mg, 1  800mg, 1  30mg, 1  500/20mg, 4.7ms
# image 772/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\891.png: 640x512 1 ()(), 1  20mg, 1  5/160mg, 1 (), 8.1ms
# image 773/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\894.png: 640x512 1 ()(), 1  5/160mg, 1  50/850mg, 1 10/5, 4.3ms
# image 774/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\895.png: 640x512 1 ()(), 1  100mg, 1  800mg, 1 (), 5.1ms
# image 775/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\896.png: 640x512 1 ()(), 1  100mg, 1  800mg, 1 (), 4.2ms
# image 776/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\897.png: 640x512 1 ()(), 1  100mg, 1  800mg, 1 (), 3.8ms
# image 777/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\898.png: 640x512 1 ()(), 1  10mg, 1  100mg, 1 , 4.3ms
# image 778/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\9.png: 640x512 1 ()(), 1  75mg, 1  50mg, 1  10/40mg, 4.4ms
# image 779/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\90.png: 640x512 1  5mg, 1  800mg, 1  30mg, 1  500/20mg, 4.0ms
# image 780/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\900.png: 640x512 1 ()(), 1  10mg, 1  100mg, 1 , 3.8ms
# image 781/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\904.png: 640x512 1 ()(), 1  75mg, 1  40/5mg, 1  2.5/850mg, 5.4ms
# image 782/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\906.png: 640x512 1 ()(), 1  75mg, 1  40/5mg, 1  2.5/850mg, 4.1ms
# image 783/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\908.png: 640x512 1  2mg, 1  75mg, 1 (), 3.9ms
# image 784/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\91.png: 640x512 1  5mg, 1  100mg, 1  10mg, 1 , 4.5ms
# image 785/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\910.png: 640x512 1 ()(), 1  50/850mg, 1  60mg, 1  4mg, 4.1ms
# image 786/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\912.png: 640x512 1 ()(), 1  50/850mg, 1  60mg, 1  4mg, 4.2ms
# image 787/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\914.png: 640x512 1  2mg, 1 ()(), 1  10/40mg, 5.3ms
# image 788/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\915.png: 640x512 1  2mg, 1 ()(), 1  10/40mg, 4.8ms
# image 789/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\916.png: 640x512 1 ()(), 1  20mg, 1  50/850mg, 1  40/5mg, 4.0ms
# image 790/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\919.png: 640x512 1 ()(), 1  40/5mg, 1  2.5/850mg, 1 10/5, 5.2ms
# image 791/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\920.png: 640x512 1 ()(), 1  40/5mg, 1  2.5/850mg, 1 10/5, 4.5ms
# image 792/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\923.png: 640x512 1 ()(), 1  20mg, 1  5/160mg, 1  50/850mg, 4.5ms
# image 793/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\925.png: 640x512 1 ()(), 1  20mg, 1  5mg, 1  50/1000mg, 4.7ms
# image 794/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\927.png: 640x512 1 ()(), 1  20mg, 1  5mg, 1  50/1000mg, 3.9ms
# image 795/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\929.png: 640x512 1 ()(), 1  20mg, 1  5/100mg, 1  100/1000mg, 5.7ms
# image 796/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\930.png: 640x512 1 ()(), 1  20mg, 1  5/100mg, 1  100/1000mg, 6.2ms
# image 797/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\931.png: 640x512 1  5mg, 1  800mg, 1  10mg, 1  500/20mg, 5.1ms
# image 798/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\932.png: 640x512 1  5mg, 1  800mg, 1  10mg, 1  500/20mg, 5.0ms
# image 799/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\933.png: 640x512 1  5mg, 1  800mg, 1  10mg, 1  500/20mg, 4.4ms
# image 800/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\936.png: 640x512 1  100mg, 1 500mg, 1  60mg/, 1  31.5mg/PTP, 6.7ms
# image 801/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\937.png: 640x512 1  100mg, 1 , 1 500mg, 1  618.6mg/, 4.4ms
# image 802/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\938.png: 640x512 1  100mg, 1 , 1 500mg, 1  618.6mg/, 9.5ms
# image 803/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\940.png: 640x512 1  2mg, 1  20mg, 1  150mg, 9.0ms
# image 804/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\941.png: 640x512 1  2mg, 1  20mg, 1  150mg, 4.4ms
# image 805/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\942.png: 640x512 1  2mg, 1  20mg, 1  150mg, 8.6ms
# image 806/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\945.png: 640x512 1 ()(), 1  5mg, 1  75mg, 1  50/850mg, 8.7ms
# image 807/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\947.png: 640x512 1 ()(), 1  20mg, 1  10/40mg, 1 (), 7.2ms
# image 808/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\948.png: 640x512 1 ()(), 1  20mg, 1  10/40mg, 1 (), 4.5ms
# image 809/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\949.png: 640x512 1 ()(), 1  20mg, 1  5/160mg, 1  2.5/850mg, 5.2ms
# image 810/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\95.png: 640x512 1  2mg, 1  4mg, 1 , 4.1ms
# image 811/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\950.png: 640x512 1 ()(), 1  20mg, 1  5/160mg, 1  2.5/850mg, 6.1ms
# image 812/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\951.png: 640x512 1 ()(), 1  20mg, 1  5/160mg, 1  2.5/850mg, 10.0ms
# image 813/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\952.png: 640x512 1 ()(), 1  20mg, 1  5/100mg, 1  2.5/850mg, 8.9ms
# image 814/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\953.png: 640x512 1 ()(), 1  20mg, 1  5/100mg, 1  2.5/850mg, 9.2ms
# image 815/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\954.png: 640x512 1 ()(), 1  20mg, 1  5/100mg, 1  2.5/850mg, 7.2ms
# image 816/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\956.png: 640x512 1  5mg, 1  800mg, 1  10mg, 1 , 4.9ms
# image 817/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\957.png: 640x512 1  5mg, 1  800mg, 1  10mg, 1 , 9.4ms
# image 818/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\962.png: 640x512 1  5mg, 1  800mg, 1  10mg, 1 , 4.2ms
# image 819/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\966.png: 640x512 1  5mg, 1  100mg, 1  30mg, 1  500/20mg, 8.2ms
# image 820/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\967.png: 640x512 1  2mg, 1  4mg, 1  25mg, 4.6ms
# image 821/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\968.png: 640x512 1  2mg, 1  4mg, 1  25mg, 9.2ms
# image 822/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\97.png: 640x512 1  5mg, 1  100mg, 1  10mg, 1  500/20mg, 5.4ms
# image 823/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\972.png: 640x512 1  5mg, 1  800mg, 1  20mg, 1 , 6.6ms
# image 824/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\973.png: 640x512 1  5mg, 1  800mg, 1  20mg, 1  500/20mg, 9.9ms
# image 825/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\974.png: 640x512 1  5mg, 1  800mg, 1  20mg, 1  500/20mg, 9.1ms
# image 826/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\975.png: 640x512 1  5mg, 1  800mg, 1  20mg, 1  500/20mg, 8.4ms
# image 827/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\979.png: 640x512 1  2mg, 1 (), 1  20mg, 8.9ms
# image 828/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\980.png: 640x512 1  2mg, 1 (), 1  20mg, 8.6ms
# image 829/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\982.png: 640x512 1  100mg, 1 , 1 8 650mg, 1  100mg/, 9.8ms
# image 830/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\983.png: 640x512 1  100mg, 1 , 1 8 650mg, 1  100mg/, 9.1ms
# image 831/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\984.png: 640x512 1  100mg, 1 , 1 8 650mg, 1  100mg/, 8.9ms
# image 832/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\985.png: 640x512 1  5mg, 1  100mg, 1  10mg, 1 , 3.8ms
# image 833/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\986.png: 640x512 1  5mg, 1  100mg, 1  10mg, 1 , 9.3ms
# image 834/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\988.png: 640x512 1 ()(), 1  5mg, 1  50mg, 1 10/5, 8.5ms
# image 835/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\989.png: 640x512 1 ()(), 1  5mg, 1  50mg, 1 10/5, 4.9ms
# image 836/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\990.png: 640x512 1 ()(), 1  5mg, 1  50mg, 1 10/5, 13.5ms
# image 837/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\991.png: 640x512 1 ()(), 1  100mg, 1  100mg, 1 (), 9.4ms
# image 838/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\993.png: 640x512 1 ()(), 1  100mg, 1  100mg, 1 (), 9.4ms
# image 839/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\994.png: 640x512 1 ()(), 1  20mg, 1  10/40mg, 1  2.5/850mg, 4.2ms
# image 840/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\996.png: 640x512 1 ()(), 1  20mg, 1  10/40mg, 1  2.5/850mg, 7.4ms
# image 841/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\997.png: 640x512 1  5mg, 1  800mg, 1  20mg, 1 , 6.2ms
# image 842/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\998.png: 640x512 1  5mg, 1  800mg, 1  20mg, 1 , 4.5ms
# image 843/843 c:\Users\dltmd\OneDrive\Desktop\testing\additional_data\test_images\999.png: 640x512 1  5mg, 1  800mg, 1  20mg, 1 , 4.0ms
# Speed: 1.0ms preprocess, 5.4ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 512)
# Results saved to runs\detect\predict
# 843 labels saved to runs\detect\predict\labels

# %%
# 설정
CONF_THRESHOLD = 0.82
NUM_CLASSES = 73
TOL = 0.01
label_dir = "./runs/detect/predict/labels"
image_dir = "./test_images"
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# 모델 로드
eff_model = timm.create_model('efficientnetv2_rw_s', pretrained=False, num_classes=NUM_CLASSES)
eff_model.load_state_dict(torch.load("./best_model.pth", map_location=device))
eff_model = eff_model.to(device)
eff_model.eval()

# 전처리
eff_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406],
                         [0.229, 0.224, 0.225])
])

# 분류 함수
def classify_with_effnet(image, xyxy):
    x1, y1, x2, y2 = map(int, xyxy)
    crop = image[y1:y2, x1:x2]
    if crop.size == 0:
        return None
    pil_crop = Image.fromarray(cv2.cvtColor(crop, cv2.COLOR_BGR2RGB))
    tensor = eff_transform(pil_crop).unsqueeze(0).to(device)
    with torch.no_grad():
        out = eff_model(tensor)
        pred = out.argmax(1).item()
    return pred

# 라벨 파일 처리
for label_file in os.listdir(label_dir):
    if not label_file.endswith(".txt"):
        continue

    image_id = Path(label_file).stem
    label_path = os.path.join(label_dir, label_file)
    image_path = os.path.join(image_dir, f"{image_id}.jpg")
    if not os.path.exists(image_path):
        image_path = os.path.join(image_dir, f"{image_id}.png")
    if not os.path.exists(image_path):
        print(f"이미지 없음: {image_id}")
        continue

    image = cv2.imread(image_path)
    if image is None:
        print(f"이미지 로딩 실패: {image_path}")
        continue

    with open(label_path, "r") as f:
        lines = f.readlines()

    updated = False
    result_boxes = []  # (class, cx, cy, w, h, conf)

    for line_num, line in enumerate(lines):
        parts = line.strip().split()
        if len(parts) != 6:
            continue

        class_id, cx, cy, w, h, conf = parts
        cx, cy, w, h, conf = map(float, [cx, cy, w, h, conf])
        class_id = int(class_id)
        original_class = class_id

        H, W = image.shape[:2]
        cx_pix, cy_pix = cx * W, cy * H
        w_pix = w * W
        h_pix = h * H
        x1 = max(0, int(cx_pix - w_pix / 2))
        y1 = max(0, int(cy_pix - h_pix / 2))
        x2 = min(W, int(cx_pix + w_pix / 2))
        y2 = min(H, int(cy_pix + h_pix / 2))

        # 신뢰도 낮은 경우 재분류
        if conf < CONF_THRESHOLD:
            new_class = classify_with_effnet(image, (x1, y1, x2, y2))
            if new_class is not None:
                # 중복 검사 (기존 결과 리스트에서)
                is_duplicate = False
                for c, ecx, ecy, ew, eh, _ in result_boxes:
                    if (c == new_class and
                        abs(cx - ecx) < TOL and abs(cy - ecy) < TOL and
                        abs(w - ew) < TOL and abs(h - eh) < TOL):
                        is_duplicate = True
                        break

                if is_duplicate:
                    print(f"🗑️ 중복으로 제거됨 → 이미지 {image_id}, 라인 {line_num}, class {new_class}")
                    continue
                else:
                    print(f"🔄 이미지 {image_id}, 라인 {line_num}: class {original_class} → {new_class}, conf {conf:.2f} → 1.00")
                    class_id = new_class
                    conf = 1.00
                    updated = True

        result_boxes.append((class_id, cx, cy, w, h, conf))

    # 저장
    with open(label_path, "w") as f:
        for c, cx, cy, w, h, conf in result_boxes:
            f.write(f"{c} {cx:.6f} {cy:.6f} {w:.6f} {h:.6f} {conf:.2f}\n")

    if updated:
        print(f"\t✅ '{label_file}' 수정 완료.")
# Out:
# 🔄 이미지 1027, 라인 2: class 20 → 20, conf 0.41 → 1.00
# 🗑️ 중복으로 제거됨 → 이미지 1027, 라인 3, class 20
# ✅ '1027.txt' 수정 완료.
# 🔄 이미지 1273, 라인 3: class 10 → 18, conf 0.73 → 1.00
# ✅ '1273.txt' 수정 완료.
# 🔄 이미지 13, 라인 2: class 20 → 20, conf 0.51 → 1.00
# ✅ '13.txt' 수정 완료.
# 🔄 이미지 1418, 라인 3: class 55 → 45, conf 0.47 → 1.00
# ✅ '1418.txt' 수정 완료.
# 🔄 이미지 409, 라인 3: class 67 → 65, conf 0.40 → 1.00
# ✅ '409.txt' 수정 완료.
# 🔄 이미지 411, 라인 3: class 45 → 65, conf 0.47 → 1.00
# ✅ '411.txt' 수정 완료.
# 🗑️ 중복으로 제거됨 → 이미지 507, 라인 3, class 60
# 🗑️ 중복으로 제거됨 → 이미지 623, 라인 3, class 38
# 🔄 이미지 747, 라인 3: class 71 → 71, conf 0.49 → 1.00
# ✅ '747.txt' 수정 완료.

# %%
# 1. class_id → category_id 매핑 로드
with open("classid_to_categoryid.json", "r", encoding="utf-8") as f:
    classid_to_categoryid = json.load(f)

# 2. 경로 설정
label_dir = "./runs/detect/predict/labels"
image_dir = "./test_images"  # 이미지 크기 참조용

# 3. 결과 저장 리스트
csv_rows = []
annotation_id = 1

# 4. 라벨 파일 순회
for label_file in sorted(os.listdir(label_dir), key=lambda x: int(Path(x).stem)):
    if not label_file.endswith(".txt"):
        continue

    image_id = int(Path(label_file).stem)
    label_path = os.path.join(label_dir, label_file)
    image_path_jpg = os.path.join(image_dir, f"{image_id}.jpg")
    image_path_png = os.path.join(image_dir, f"{image_id}.png")

    # 이미지 크기 가져오기
    import cv2
    if os.path.exists(image_path_jpg):
        image = cv2.imread(image_path_jpg)
    elif os.path.exists(image_path_png):
        image = cv2.imread(image_path_png)
    else:
        print(f"⚠️ 이미지 {image_id} 없음. 건너뜀.")
        continue

    H, W = image.shape[:2]

    with open(label_path, "r") as f:
        for line in f:
            parts = line.strip().split()
            if len(parts) != 6:
                continue

            class_id, cx, cy, w, h, conf = parts
            class_id = int(class_id)
            if str(class_id) not in classid_to_categoryid:
                print(f"⚠️ class_id {class_id} 매핑 없음. 건너뜀.")
                continue
            category_id = int(classid_to_categoryid[str(class_id)])

            cx, cy, w, h, conf = map(float, [cx, cy, w, h, conf])
            bbox_x = int((cx - w / 2) * W)
            bbox_y = int((cy - h / 2) * H)
            bbox_w = int(w * W)
            bbox_h = int(h * H)

            csv_rows.append([
                annotation_id,
                image_id,
                category_id,
                bbox_x,
                bbox_y,
                bbox_w,
                bbox_h,
                round(conf, 2)
            ])
            annotation_id += 1

# 5. DataFrame 저장
df = pd.DataFrame(csv_rows, columns=[
    "annotation_id", "image_id", "category_id",
    "bbox_x", "bbox_y", "bbox_w", "bbox_h", "score"
])
df.to_csv("submission_formatted.csv", index=False)

print("제출용 CSV 저장 완료: submission_formatted.csv")
# Out:
# ✅ 제출용 CSV 저장 완료: submission_formatted.csv
